# %% [markdown]
# # Assignment #12: Solve the following questions.
# Q1. You have to create a function which will take a batsman name as input and plot a 2d plot/line plot depicting his sesaon by season performance(in terms of runs scored per season)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('matches-Copy1.csv')
match=pd.read_csv('deliveries-Copy1.csv')

# %%
m=data.merge(match,left_on="id",right_on="match_id") # data sheet needed to be merged

# %%
def stats(batsman):
    bats=batsman
    m[m['batsman']==batsman].groupby("season")['batsman_runs'].sum().plot(kind='line',figsize=(10,8),label=bats)
    plt.xlabel("Season")
    plt.ylabel("Runs")
    plt.title("Batsman And Its Statistics")
    plt.legend()
    return plt.show()

# %%
stats("V Kohli")

# %%
stats("CH Gayle")

# %% [markdown]
# # Probelm came

# %%
k=match.groupby("batsman")['batsman_runs'].sum().sort_values(ascending=False).head(10)
k

x=k.index
y=k.values

# %%
x=x.tolist()

# %%
y=y.tolist()

# %%
plt.bar(x,y)
plt.xlabel("BATSMAN")
plt.ylabel("Runs")
plt.title("BATSMAN VS RUNS")
# Out:
# Text(0.5, 1.0, 'BATSMAN VS RUNS')

# %%
#but found another better method

# %%
data[data['winner']=='Mumbai Indians']['player_of_match'].value_counts().plot(kind='bar',figsize=(10,8))

# %%
match
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
mask1=match.batsman_runs==1 
mask2=match.batsman_runs=2
mask3=match.batsman_runs=3
mask4=match.batsman_runs=4
mask6= match.batsman_runs=6

# %%
match[mask1 | mask2 | mask3| mask4| mask6]
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...

# %%
match
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# 5              1       1          Sunrisers Hyderabad
# 6              1       1          Sunrisers Hyderabad
# 7              1       1          Sunrisers Hyderabad
# 8              1       1          Sunrisers Hyderabad
# 9              1       1          Sunrisers Hyderabad
# 10             1       1          Sunrisers Hyderabad
# 11             1       1          Sunrisers Hyderabad
# 12             1       1          Sunrisers Hyderabad
# 13             1       1          Sunrisers Hyderabad
# 14             1       1          Sunrisers Hyderabad
# 15             1       1          Sunrisers Hyderabad
# ...
